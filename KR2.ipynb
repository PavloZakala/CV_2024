# %%
from torchvision import datasets

cifar100_dataset = datasets.CIFAR100("dataset", download=True)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████| 169001437/169001437 [00:08<00:00, 20387394.39it/s]
# Extracting dataset\cifar-100-python.tar.gz to dataset

# %%
from matplotlib import pyplot as plt

plt.hist(cifar100_dataset.targets, bins=100)
# Out:
# (array([500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#         500.]),
#  array([ 0.  ,  0.99,  1.98,  2.97,  3.96,  4.95,  5.94,  6.93,  7.92,
#          8.91,  9.9 , 10.89, 11.88, 12.87, 13.86, 14.85, 15.84, 16.83,
#         17.82, 18.81, 19.8 , 20.79, 21.78, 22.77, 23.76, 24.75, 25.74,
#         26.73, 27.72, 28.71, 29.7 , 30.69, 31.68, 32.67, 33.66, 34.65,
# ...
